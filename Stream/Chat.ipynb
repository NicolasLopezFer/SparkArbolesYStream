# %%
from pyspark import SparkContext

# %%
from pyspark.streaming import StreamingContext

# %%
sc = SparkContext('local[2]','NetworkWordCount')

# %%
ssc = StreamingContext(sc,1)

# %%
lines = ssc.socketTextStream('localhost', 9999)

# %%
words = lines.flatMap(lambda line: line.split(' '))

# %%
pairs = words.map(lambda word:(word,1))

# %%
word_counts = pairs.reduceByKey(lambda num1,num2: num1+num2)

# %%
word_counts.pprint()

# %%
ssc.start()
# Out:
# -------------------------------------------
# Time: 2021-03-15 19:59:50
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-15 19:59:51
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-15 19:59:52
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-15 19:59:53
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-15 19:59:54
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-15 19:59:55
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-15 19:59:56
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-15 19:59:57
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-15 19:59:58
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-15 19:59:59
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-15 20:00:00
# -------------------------------------------
# ('Hola', 1)
#
# -------------------------------------------
# Time: 2021-03-15 20:00:01
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-15 20:00:02
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-15 20:00:03
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-15 20:00:04
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-15 20:00:05
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-15 20:00:06
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-15 20:00:07
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-15 20:00:08
# -------------------------------------------
# ('Este', 1)
# ('con', 1)
# ('muchas', 1)
# ('un', 1)
# ('mensaje', 1)
# ('palabras', 1)
#
# -------------------------------------------
# Time: 2021-03-15 20:00:09
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-15 20:00:10
# -------------------------------------------
# ('hola', 3)
#
# -------------------------------------------
# Time: 2021-03-15 20:00:11
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-15 20:00:12
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-15 20:00:13
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-15 20:00:14
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-15 20:00:15
# -------------------------------------------
